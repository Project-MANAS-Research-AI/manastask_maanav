# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
class svm_classifier():
    def __init__(self, lr, noi, lambdap):
        self.lr = lr
        self.noi = noi
        self.lambdap = lambdap
    
    def fit(self, x, y):
        self.m, self.n = x.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.x = x
        self.y = y
        for i in range(self.noi):
            self.update_weights()
    def update_weights(self):
        y_label = np.where(self.y <= 0, -1, 1)
        for index, x_i in enumerate(self.x):
            condition = y_label[index]*(np.dot(x_i, self.w) - self.b) >= 1
            if(condition == True):
                dw = 2*self.lambdap*self.w
                db = 0
            else: 
                dw = 2+self.lambdap*self.w - np.dot(x_i, y_label[index])
                db = y_label[index]
        self.w = self.w - self.lr*dw
        self.b = self.b - self.lr*db
    def predict(self, x):
        output = np.dot(x, self.w) - self.b
        pred_label = np.sign(output)
        y_hat = np.where(pred_label <= -1, 0, 1)
        return y_hat

# %%
data = pd.read_csv('archive\pulsar_data_train.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\user\AppData\Local\Temp\ipykernel_25260\1724867407.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data = pd.read_csv('archive\pulsar_data_train.csv')
#         Mean of the integrated profile  \
# 0                           121.156250
# 1                            76.968750
# 2                           130.585938
# 3                           156.398438
# 4                            84.804688
# ...                                ...
# 12523                       124.312500
# 12524                       115.617188
# 12525                       116.031250
# 12526                       135.664062
# 12527                       120.726562
#
#         Standard deviation of the integrated profile  \
# 0                                          48.372971
# 1                                          36.175557
# 2                                          53.229534
# ...

# %%
features = data.iloc[:, :-1].values.astype(float)
outcomes = data.iloc[:, -1].values.astype(int)
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
model = svm_classifier(lr = 0.001, noi = 1000, lambdap = 0.01)
model.fit(features, outcomes)

# %%
data2 = pd.read_csv('archive\pulsar_data_train.csv')
features2 = data2.iloc[:, :-1].values.astype(float)
outcomes2 = data2.iloc[:, -1].values.astype(int)
features2 = scaler.fit_transform(features2)

predict2 = model.predict(features2)
acc = accuracy_score(outcomes2, predict2)
print(f'the accuracy is {acc}')
# Out:
# the accuracy is 0.4194604086845466
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\user\AppData\Local\Temp\ipykernel_25260\694129726.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data2 = pd.read_csv('archive\pulsar_data_train.csv')
